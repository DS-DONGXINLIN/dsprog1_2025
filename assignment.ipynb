# %%
import requests
from bs4 import BeautifulSoup
import time
import urllib.parse

start_url = "https://www.musashino-u.ac.jp/"
visited = set()
pages = {}

# %%
def is_same_domain(url):
    domain = urllib.parse.urlparse(url).netloc
    return ("musashino-u.ac.jp" in domain) or (domain == "")

def get_absolute_url(base, link):
    return urllib.parse.urljoin(base, link)

def crawl(url):
    print("アクセス中:", url)
    # time.sleep(1)

    res = requests.get(url)
    soup = BeautifulSoup(res.text, "html.parser")

    title = soup.find("title")
    if title:
        pages[url] = title.get_text(strip=True)
    else:
        pages[url] = ""

    links = soup.find_all("a", href=True)

    for tag in links:
        link = tag["href"]
        full_url = get_absolute_url(url, link)

        if is_same_domain(full_url) and full_url not in visited:
            visited.add(full_url)
            crawl(full_url)

visited.add(start_url)
crawl(start_url)
# Out:
# アクセス中: https://www.musashino-u.ac.jp/
# アクセス中: https://www.musashino-u.ac.jp/#main
# アクセス中: https://ef.musashino-u.ac.jp/donation/
# アクセス中: https://ef.musashino-u.ac.jp/donation/#main
# アクセス中: https://ef.musashino-u.ac.jp/
# アクセス中: https://ef.musashino-u.ac.jp/#main
# アクセス中: https://ef.musashino-u.ac.jp/about/
# アクセス中: https://ef.musashino-u.ac.jp/about/#main
# アクセス中: https://ef.musashino-u.ac.jp/about/message/
# アクセス中: https://ef.musashino-u.ac.jp/about/message/#main
# アクセス中: https://ef.musashino-u.ac.jp/about/history/
# アクセス中: https://ef.musashino-u.ac.jp/about/history/#main
# アクセス中: https://ef.musashino-u.ac.jp/about/granddesign/
# アクセス中: https://ef.musashino-u.ac.jp/about/granddesign/#main
# アクセス中: https://ef.musashino-u.ac.jp/about/vision/
# アクセス中: https://ef.musashino-u.ac.jp/about/vision/#main
# アクセス中: https://ef.musashino-u.ac.jp/about/schools/
# アクセス中: https://ef.musashino-u.ac.jp/about/schools/#main
# アクセス中: https://ef.musashino-u.ac.jp/about/pamphlet/
# アクセス中: https://ef.musashino-u.ac.jp/about/pamphlet/#main
# アクセス中: https://ef.musashino-u.ac.jp/about/journal/
# アクセス中: https://ef.musashino-u.ac.jp/about/journal/#main
# アクセス中: https://ef.musashino-u.ac.jp/about/#basic
# アクセス中: https://ef.musashino-u.ac.jp/about/#financial
# アクセス中: https://ef.musashino-u.ac.jp/about/#facilities
# アクセス中: https://ef.musashino-u.ac.jp/about/#audit
# アクセス中: https://ef.musashino-u.ac.jp/about/#policies
# アクセス中: https://ef.musashino-u.ac.jp/about/#application
# アクセス中: https://ef.musashino-u.ac.jp/news/2025/?category=æ´»åã¬ãã¼ã
# アクセス中: https://ef.musashino-u.ac.jp/news/2025/?category=æ´»åã¬ãã¼ã#main
# アクセス中: https://ef.musashino-u.ac.jp/news/2025/?category=活動レポート
# アクセス中: https://ef.musashino-u.ac.jp/news/2025/?category=活動レポート#main
# アクセス中: https://ef.musashino-u.ac.jp/news/
# アクセス中: https://www.musashino-u.ac.jp/admission/
# アクセス中: https://www.musashino-u.ac.jp/admission/#main
# アクセス中: https://www.musashino-u.ac.jp/admission/faculty/
# アクセス中: https://www.musashino-u.ac.jp/admission/faculty/#main
# アクセス中: https://www.musashino-u.ac.jp/admission/international_students/
# アクセス中: https://www.musashino-u.ac.jp/admission/international_students/#main
# アクセス中: https://www.musashino-u.ac.jp/admission/graduate_school/
# アクセス中: https://www.musashino-u.ac.jp/admission/graduate_school/#main
# アクセス中: https://www.musashino-u.ac.jp/admission/advanced_course/
# アクセス中: https://www.musashino-u.ac.jp/admission/advanced_course/#main
# アクセス中: https://www.musashino-u.ac.jp/admission/short_term_course/
# アクセス中: https://www.musashino-u.ac.jp/admission/short_term_course/#main
# アクセス中: https://www.musashino-u.ac.jp/admission/event/
# アクセス中: https://www.musashino-u.ac.jp/admission/event/#main
# アクセス中: https://www.musashino-u.ac.jp/admission/faq/
# アクセス中: https://www.musashino-u.ac.jp/admission/faq/#main
# アクセス中: https://www.musashino-u.ac.jp/admission/download/
# アクセス中: https://www.musashino-u.ac.jp/admission/download/#main
# アクセス中: https://www.musashino-u.ac.jp/basic/
# アクセス中: https://www.musashino-u.ac.jp/basic/#main
# アクセス中: https://www.musashino-u.ac.jp/basic/purpose.html
# アクセス中: https://www.musashino-u.ac.jp/basic/purpose.html#main
# アクセス中: https://www.musashino-u.ac.jp/basic/policies/
# アクセス中: https://www.musashino-u.ac.jp/basic/policies/#main
# アクセス中: https://www.musashino-u.ac.jp/basic/learning_cycle.html
# アクセス中: https://www.musashino-u.ac.jp/basic/learning_cycle.html#main
# アクセス中: https://www.musashino-u.ac.jp/basic/initial/
# アクセス中: https://www.musashino-u.ac.jp/basic/initial/#main
# アクセス中: https://www.musashino-u.ac.jp/basic/endowment_course.html
# アクセス中: https://www.musashino-u.ac.jp/basic/endowment_course.html#main
# アクセス中: https://www.musashino-u.ac.jp/basic/consortium.html
# アクセス中: https://www.musashino-u.ac.jp/basic/consortium.html#main
# アクセス中: https://www.musashino-u.ac.jp/basic/generation_ai/index.html
# アクセス中: https://www.musashino-u.ac.jp/basic/generation_ai/index.html#main
# アクセス中: https://www.musashino-u.ac.jp/academics/
# アクセス中: https://www.musashino-u.ac.jp/academics/#main
# アクセス中: https://www.musashino-u.ac.jp/academics/faculty/
# アクセス中: https://www.musashino-u.ac.jp/academics/faculty/#main
# アクセス中: https://www.musashino-u.ac.jp/academics/graduate_school/
# アクセス中: https://www.musashino-u.ac.jp/academics/graduate_school/#main
# アクセス中: https://dl.musashino-u.ac.jp/
# アクセス中: https://dl.musashino-u.ac.jp/#main
# アクセス中: https://dl.musashino-u.ac.jp/request/
# アクセス中: https://dl.musashino-u.ac.jp/request/#main
# アクセス中: https://dl.musashino-u.ac.jp/contact/
# アクセス中: https://wbt.musashino-u.ac.jp/wbtportal/linkmenuforward.do;jsessionid=BC21554840BD9C912EF4F5618E9CBA70?linkUrl=https%3a%2f%2fdl.musashino-u.ac.jp%2f#main
# アクセス中: https://wbt.musashino-u.ac.jp/
# アクセス中: https://wbt.musashino-u.ac.jp/request/
# アクセス中: https://wbt.musashino-u.ac.jp/contact/
# アクセス中: https://wbt.musashino-u.ac.jp/admission/internet_application/
# アクセス中: https://wbt.musashino-u.ac.jp/guide/
# アクセス中: https://wbt.musashino-u.ac.jp/guide/outline/
# アクセス中: https://wbt.musashino-u.ac.jp/guide/wbt/
# アクセス中: https://wbt.musashino-u.ac.jp/guide/schedule/
# アクセス中: https://wbt.musashino-u.ac.jp/guide/how_to_study/
# アクセス中: https://wbt.musashino-u.ac.jp/guide/guide_study/
# アクセス中: https://wbt.musashino-u.ac.jp/guide/academic_support/
# アクセス中: https://wbt.musashino-u.ac.jp/guide/fees/
# アクセス中: https://wbt.musashino-u.ac.jp/guide/application/
# アクセス中: https://wbt.musashino-u.ac.jp/academics/
# アクセス中: https://wbt.musashino-u.ac.jp/academics/human_sciences/
# アクセス中: https://wbt.musashino-u.ac.jp/academics/education/
# アクセス中: https://wbt.musashino-u.ac.jp/academics/human_and_social_sciences/
# アクセス中: https://wbt.musashino-u.ac.jp/academics/buddhist_studies/
# アクセス中: https://wbt.musashino-u.ac.jp/academics/environmental_science/
# アクセス中: https://wbt.musashino-u.ac.jp/academics/license_law/
# アクセス中: https://wbt.musashino-u.ac.jp/academics/interview/
# アクセス中: https://wbt.musashino-u.ac.jp/academics/teacher/
# アクセス中: https://wbt.musashino-u.ac.jp/qualification/
# アクセス中: https://wbt.musashino-u.ac.jp/qualification/social_worker/
# アクセス中: https://wbt.musashino-u.ac.jp/qualification/certified_psychologist/
# アクセス中: https://wbt.musashino-u.ac.jp/qualification/industrial_counselor/
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 32
#      29             crawl(full_url)
#      31 visited.add(start_url)
# ---> 32 crawl(start_url)
#
# Cell In[2], line 29, in crawl(url)
#      27 if is_same_domain(full_url) and full_url not in visited:
#      28     visited.add(full_url)
# ---> 29     crawl(full_url)
#
# Cell In[2], line 29, in crawl(url)
#      27 if is_same_domain(full_url) and full_url not in visited:
#      28     visited.add(full_url)
# ---> 29     crawl(full_url)
#
#     [... skipping similar frames: crawl at line 29 (127 times)]
#
# Cell In[2], line 29, in crawl(url)
#      27 if is_same_domain(full_url) and full_url not in visited:
#      28     visited.add(full_url)
# ---> 29     crawl(full_url)
#
# Cell In[2], line 10, in crawl(url)
#       8 def crawl(url):
#       9     print("アクセス中:", url)
# ---> 10     time.sleep(1)
#      12     res = requests.get(url)
#      13     soup = BeautifulSoup(res.text, "html.parser")
#
# KeyboardInterrupt:

# %%
print("\n===== 抽出結果 =====")
for url, title in pages.items():
    print(url, " -> ", title)
