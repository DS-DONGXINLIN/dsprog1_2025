# %%
import requests
from bs4 import BeautifulSoup
import time
import urllib.parse

start_url = "https://www.musashino-u.ac.jp/"
visited = set()
pages = {}

# %%
def is_same_domain(url):
    domain = urllib.parse.urlparse(url).netloc
    return ("musashino-u.ac.jp" in domain) or (domain == "")

def get_absolute_url(base, link):
    return urllib.parse.urljoin(base, link)

def crawl(url):
    print("アクセス中:", url)
    # time.sleep(1)

    res = requests.get(url)
    soup = BeautifulSoup(res.text, "html.parser")

    title = soup.find("title")
    if title:
        pages[url] = title.get_text(strip=True)
    else:
        pages[url] = ""

    links = soup.find_all("a", href=True)

    for tag in links:
        link = tag["href"]
        full_url = get_absolute_url(url, link)
        if href.startswith("mailto:"):
            continue
        if is_same_domain(full_url) and full_url not in visited:
            visited.add(full_url)
            crawl(full_url)

visited.add(start_url)
crawl(start_url)
# Out:
# アクセス中: https://www.musashino-u.ac.jp/
# アクセス中: https://www.musashino-u.ac.jp/academics/advanced_course/
# アクセス中: https://www.musashino-u.ac.jp/academics/advanced_course/#main
# アクセス中: https://www.musashino-u.ac.jp/academics/special_course/
# アクセス中: https://www.musashino-u.ac.jp/academics/special_course/#main
# アクセス中: https://www.musashino-u.ac.jp/academics/Lifelong_learning/
# アクセス中: https://www.musashino-u.ac.jp/academics/Lifelong_learning/#main
# アクセス中: https://www.musashino-u.ac.jp/academics/teachers_license/
# アクセス中: https://www.musashino-u.ac.jp/academics/teachers_license/#main
# アクセス中: https://www.musashino-u.ac.jp/research/
# アクセス中: https://www.musashino-u.ac.jp/research/#main
# アクセス中: https://www.musashino-u.ac.jp/research/laboratory/
# アクセス中: https://www.musashino-u.ac.jp/research/laboratory/#main
# アクセス中: https://www.musashino-u.ac.jp/research/kakenhi/
# アクセス中: https://www.musashino-u.ac.jp/research/kakenhi/#main
# アクセス中: https://www.musashino-u.ac.jp/research/cooperation/
# アクセス中: https://www.musashino-u.ac.jp/research/cooperation/#main
# アクセス中: https://www.musashino-u.ac.jp/research/ethics/
# アクセス中: https://www.musashino-u.ac.jp/research/ethics/#main
# アクセス中: https://www.musashino-u.ac.jp/research/interview/
# アクセス中: https://www.musashino-u.ac.jp/research/interview/#main
# アクセス中: https://www.musashino-u.ac.jp/research/alignment/collaborativeresearch.html
# アクセス中: https://www.musashino-u.ac.jp/research/alignment/collaborativeresearch.html#main
# アクセス中: https://www.musashino-u.ac.jp/international/
# アクセス中: https://www.musashino-u.ac.jp/international/#main
# アクセス中: https://www.musashino-u.ac.jp/international/international-center/
# アクセス中: https://www.musashino-u.ac.jp/international/international-center/#main
# アクセス中: https://www.musashino-u.ac.jp/international/study-abroad/
# アクセス中: https://www.musashino-u.ac.jp/international/study-abroad/#main
# アクセス中: https://www.musashino-u.ac.jp/international/international-students/
# アクセス中: https://www.musashino-u.ac.jp/international/international-students/#main
# アクセス中: https://www.musashino-u.ac.jp/international/events/
# アクセス中: https://www.musashino-u.ac.jp/international/events/#main
# アクセス中: https://www.musashino-u.ac.jp/international/research_results/
# アクセス中: https://www.musashino-u.ac.jp/international/research_results/#main
# アクセス中: https://www.musashino-u.ac.jp/international/gc_portal/
# アクセス中: https://www.musashino-u.ac.jp/international/gc_portal/#main
# アクセス中: https://www.musashino-u.ac.jp/basic/initial/index.html#anchor6
# アクセス中: https://www.musashino-u.ac.jp/basic/initial/index.html#anchor7
# アクセス中: https://www.musashino-u.ac.jp/guide/facility/MUSIC_center/submajor_aiexpert.html
# アクセス中: https://www.musashino-u.ac.jp/guide/facility/MUSIC_center/submajor_aiexpert.html#main
# アクセス中: https://www.musashino-u.ac.jp/guide/facility/MUSIC_center/
# アクセス中: https://www.musashino-u.ac.jp/guide/facility/MUSIC_center/#main
# アクセス中: https://www.musashino-u.ac.jp/student-life/campus_life/calendar.html
# アクセス中: https://www.musashino-u.ac.jp/student-life/campus_life/calendar.html#main
# アクセス中: https://www.musashino-u.ac.jp/student-life/campus_life
# アクセス中: https://www.musashino-u.ac.jp/student-life/campus_life#main
# アクセス中: https://www.musashino-u.ac.jp/student-life/campus_life/time.html
# アクセス中: https://www.musashino-u.ac.jp/student-life/campus_life/time.html#main
# アクセス中: https://www.musashino-u.ac.jp/student-life/learning/register.html
# アクセス中: https://www.musashino-u.ac.jp/student-life/learning/register.html#main
# アクセス中: https://www.musashino-u.ac.jp/student-life/learning
# アクセス中: https://www.musashino-u.ac.jp/student-life/learning#main
# アクセス中: https://www.musashino-u.ac.jp/student-life/learning/consideration.html
# アクセス中: https://www.musashino-u.ac.jp/student-life/learning/consideration.html#main
# アクセス中: mailto:gakusei@musashino-u.ac.jp
# ---------------------------------------------------------------------------
# InvalidSchema                             Traceback (most recent call last)
# Cell In[3], line 32
#      29             crawl(full_url)
#      31 visited.add(start_url)
# ---> 32 crawl(start_url)
#
# Cell In[3], line 29, in crawl(url)
#      27 if is_same_domain(full_url) and full_url not in visited:
#      28     visited.add(full_url)
# ---> 29     crawl(full_url)
#
# Cell In[3], line 29, in crawl(url)
#      27 if is_same_domain(full_url) and full_url not in visited:
#      28     visited.add(full_url)
# ---> 29     crawl(full_url)
#
#     [... skipping similar frames: crawl at line 29 (104 times)]
#
# Cell In[3], line 29, in crawl(url)
#      27 if is_same_domain(full_url) and full_url not in visited:
#      28     visited.add(full_url)
# ---> 29     crawl(full_url)
#
# Cell In[3], line 12, in crawl(url)
#       9 print("アクセス中:", url)
#      10 # time.sleep(1)
# ---> 12 res = requests.get(url)
#      13 soup = BeautifulSoup(res.text, "html.parser")
#      15 title = soup.find("title")
#
# File ~/DS program/DSprog1/dsprog1_2025/.venv/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/DS program/DSprog1/dsprog1_2025/.venv/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/DS program/DSprog1/dsprog1_2025/.venv/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/DS program/DSprog1/dsprog1_2025/.venv/lib/python3.12/site-packages/requests/sessions.py:697, in Session.send(self, request, **kwargs)
#     694 hooks = request.hooks
#     696 # Get the appropriate adapter to use
# --> 697 adapter = self.get_adapter(url=request.url)
#     699 # Start time (approximately) of the request
#     700 start = preferred_clock()
#
# File ~/DS program/DSprog1/dsprog1_2025/.venv/lib/python3.12/site-packages/requests/sessions.py:792, in Session.get_adapter(self, url)
#     789         return adapter
#     791 # Nothing matches :-/
# --> 792 raise InvalidSchema(f"No connection adapters were found for {url!r}")
#
# InvalidSchema: No connection adapters were found for 'mailto:gakusei@musashino-u.ac.jp'

# %%
print("\n===== 抽出結果 =====")
for url, title in pages.items():
    print(url, " -> ", title)
